# %%
import pandas as pd
clean_df = pd.read_csv(
    "../data/processed/transactions_clean.csv"
)

clean_df.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           invoice_date  unit_price  customer_id         country  \
# 0  2010-12-01 08:26:00        2.55      17850.0  United Kingdom
# 1  2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 2  2010-12-01 08:26:00        2.75      17850.0  United Kingdom
# 3  2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 4  2010-12-01 08:26:00        3.39      17850.0  United Kingdom
#
#    is_cancellation  revenue  year  month year_month day_of_week  hour  \
# 0            False    15.30  2010     12    2010-12   Wednesday     8
# 1            False    20.34  2010     12    2010-12   Wednesday     8
# 2            False    22.00  2010     12    2010-12   Wednesday     8
# 3            False    20.34  2010     12    2010-12   Wednesday     8
# 4            False    20.34  2010     12    2010-12   Wednesday     8
#
#    has_customer_id
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True

# %%
clean_df.shape
# Out:
# (534129, 16)

# %%
# Check the data types of all columns
print(clean_df.dtypes)
# Out:
# invoice_no             str
# stock_code             str
# description            str
# quantity             int64
# invoice_date           str
# unit_price         float64
# customer_id        float64
# country                str
# is_cancellation       bool
# revenue            float64
# year                 int64
# month                int64
# year_month             str
# day_of_week            str
# hour                 int64
# has_customer_id       bool
# dtype: object

# %%
clean_df.isna().sum()
# Out:
# invoice_no              0
# stock_code              0
# description             0
# quantity                0
# invoice_date            0
# unit_price              0
# customer_id        132565
# country                 0
# is_cancellation         0
# revenue                 0
# year                    0
# month                   0
# year_month              0
# day_of_week             0
# hour                    0
# has_customer_id         0
# dtype: int64

# %%
clean_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
clean_df["unit_price"].min()
# Out:
# np.float64(0.001)

# %%
clean_df["revenue"].describe()
# Out:
# count    534129.000000
# mean         18.250518
# std         380.945385
# min     -168469.600000
# 25%           3.750000
# 50%           9.900000
# 75%          17.570000
# max      168469.600000
# Name: revenue, dtype: float64

# %%
clean_df["is_cancellation"].value_counts()
# Out:
# is_cancellation
# False    524878
# True       9251
# Name: count, dtype: int64
